# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('marketing_customer_analysis.csv')
data.shape
# Out:
# (10910, 26)

# %%
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
data = data.drop(['Unnamed: 0'],axis=1)
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
col_std = []
for col in data.columns:
    col_std.append(col.lower())
data.columns = col_std

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
data.dtypes
data.select_dtypes(np.number)
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
data.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# ...

# %%
data = data.drop(['vehicle type' ], axis =1)
data.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'response', 'coverage',
#        'education', 'effective to date', 'employmentstatus', 'gender',
#        'income', 'location code', 'marital status', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies', 'policy type',
#        'policy', 'renew offer type', 'sales channel', 'total claim amount',
#        'vehicle class', 'vehicle size'],
#       dtype='object')

# %%
data = data.dropna()

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
pd.DatetimeIndex(data['effective to date']).month
# Out:
# Int64Index([2, 1, 2, 1, 2, 2, 1, 1, 1, 1,
#             ...
#             1, 2, 2, 1, 1, 1, 2, 1, 2, 2],
#            dtype='int64', name='effective to date', length=9134)

# %%
data['month'] = pd.DatetimeIndex(data['effective to date']).month
data

#cant figure out why I dont have the column month
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
data = pd.read_csv('marketing_customer_analysis.csv')

# %%
def clean_data(df):
    df

# %%
ROUND 3 -- I tried my best to make it work with both my group and by myself but most formulas keep giving me an error
# Out:
#   Input In [229]
#     ROUND 3
#           ^
# SyntaxError: invalid syntax

# %%
data

# %%
data.describe().T

# %%
import seaborn as sns
sns.countplot("response", data = data)

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
ROUND 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.dtypes

# %%
numerical = data.select_dtypes(np.number)    #categorical vs numerical values
categorical = data.select_dtypes('object')

numerical.head()

# %%
numerical.describe().T

# %%
numerical

# %%
sns.set(rc = {'figure.figsize':(15,15)})

# %%
for column in numerical.columns:   
    sns.boxplot(x=numerical[column])
    plt.show()
    iqr = np.percentile(numerical[column],75) - np.percentile(numerical[column],25)
    data2 = numerical[(numerical[column]>np.percentile(numerical[column],25) - 1*iqr) & (numerical[column]<np.percentile(numerical[column],75) + 1*iqr)].copy()
    sns.displot(data2[column])
    plt.show()

# %%
numerical.hist(bins=10, figsize=(10, 10))
#we watch the histograms as requested
# Out:
# array([[<AxesSubplot:title={'center':'unnamed: 0'}>,
#         <AxesSubplot:title={'center':'customer lifetime value'}>,
#         <AxesSubplot:title={'center':'income'}>],
#        [<AxesSubplot:title={'center':'monthly premium auto'}>,
#         <AxesSubplot:title={'center':'months since last claim'}>,
#         <AxesSubplot:title={'center':'months since policy inception'}>],
#        [<AxesSubplot:title={'center':'number of open complaints'}>,
#         <AxesSubplot:title={'center':'number of policies'}>,
#         <AxesSubplot:title={'center':'total claim amount'}>]],
#       dtype=object)

# %%
iqr = np.percentile(numerical['monthly premium auto'],75) - np.percentile(numerical['monthly premium auto'],25)
numerical = numerical[(numerical['monthly premium auto']>np.percentile(numerical['monthly premium auto'],25) - 1*iqr) & (numerical['monthly premium auto']<np.percentile(numerical['monthly premium auto'],75) + 1*iqr)].copy()

numerical.describe().T

#cant get this formula to work.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\anaconda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Desktop\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Desktop\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'monthly premium auto'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
correlations_matrix = data.corr()
sns.set(rc = {'figure.figsize':(15,15)})
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

y = numerical['total claim amount']
X = numerical.drop(['total claim_amount', 'month'], axis=1)

lm = linear_model.LinearRegression()
lm.fit(X,y)

regression_line = lm.intercept_ + lm.coef_[0]*numerical['total claim amount']
#Results from infinity to one, usually good if values 0.5-0.85
print("R2-score is ", lm.score(X,y))

# This return the average error for each prediction
print("mean squared error (MSE) is ", np.sqrt(mean_squared_error(lm.predict(X),y)))

# %%
#this formula obviusly doesent work. Really want to check this tomorrow.

# %%
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler

X_num = X.select_dtypes(include = np.number)
X_cat = X.select_dtypes(include = object)


transformer = MinMaxScaler().fit(X_num)
x_normalized = transformer.transform(X_num)
x_normalized = pd.DataFrame(x_normalized, columns=X_num.columns)

x_normalized.describe().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [236], in <cell line: 4>()
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 from sklearn.preprocessing import StandardScaler
# ----> 4 X_num = X.select_dtypes(include = np.number)
#       5 X_cat = X.select_dtypes(include = object)
#       8 transformer = MinMaxScaler().fit(X_num)
#
# NameError: name 'X' is not defined
